# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
random_image = np.random.randint(0, 256, (100, 100), dtype=np.uint8)
RGB_image = cv2.cvtColor(random_image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 4))
plt.imshow(RGB_image)

# %%
resized_image = cv2.resize(image, (64,64))

# %%
resized_image
# Out:
# array([[[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 254, 252],
#         [254, 254, 254],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [252, 252, 252],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [248, 248, 249],
#         [251, 251, 251],
#         [253, 253, 253]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [254, 254, 254],
#         [253, 253, 253]],
#
#        [[254, 254, 254],
#         [253, 253, 253],
#         [253, 253, 253],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [253, 253, 253],
# ...

# %%
gt = cv2.imread("D:/data/th.jpg")
plt.imshow(gt)

# %%
rgbgt = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgbgt)

# %%
resized_image = cv2.resize(rgbgt, (64, 64),interpolation=cv2.INTER_AREA)

# %%
plt.imshow(resized_image)

# %%
resized_image = cv2.resize(rgbgt, (64,64), interpolation=cv2.INTER_AREA)
plt.imshow(resized_image)

# %%
resized_image = cv2.resize(rgbgt, (10,10), interpolation=cv2.INTER_AREA)
plt.imshow(resized_image)

# %%
blurred_image = cv2.GaussianBlur(rgbgt, (5, 5), 0)

# %%
plt.subplot(1,2,2)
plt.imshow(median_filtered_img )
plt.title('Median')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.imshow(blurred_image )
plt.title('Blurred')
# Out:
# Text(0.5, 1.0, 'Blurred')

# %%
median_filtered_img = cv2.medianBlur(rgbgt, 5)

# %%
plt.subplot(1,2,2)
plt.imshow(median_filtered_img )
plt.title('Median')
plt.show()

# %%
gray_gt= cv2.cvtColor(rgbgt,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(12,4))
plt.imshow(gray_gt, cmap='gray')
plt.title("Gray Scale")
plt.show()

# %%
gray_gt
# Out:
# array([[253, 253, 254, ..., 252, 252, 252],
#        [252, 253, 253, ..., 253, 253, 253],
#        [252, 253, 253, ..., 253, 253, 253],
#        ...,
#        [254, 254, 255, ..., 253, 253, 253],
#        [254, 254, 254, ..., 253, 253, 253],
#        [253, 254, 254, ..., 253, 253, 253]], dtype=uint8)

# %%
normalized_gray_gt = gray_gt/255
plt.figure(figsize=(12, 4))
plt.imshow(normalized_gray_gt, cmap='gray')
plt.title('Noramlized')
plt.show()
print(normalized_gray_gt)
# Out:
# [[0.99215686 0.99215686 0.99607843 ... 0.98823529 0.98823529 0.98823529]
#  [0.98823529 0.99215686 0.99215686 ... 0.99215686 0.99215686 0.99215686]
#  [0.98823529 0.99215686 0.99215686 ... 0.99215686 0.99215686 0.99215686]
#  ...
#  [0.99607843 0.99607843 1.         ... 0.99215686 0.99215686 0.99215686]
#  [0.99607843 0.99607843 0.99607843 ... 0.99215686 0.99215686 0.99215686]
#  [0.99215686 0.99607843 0.99607843 ... 0.99215686 0.99215686 0.99215686]]

# %%
filp = cv2.flip(normalized_gray_gt, -1)
plt.imshow(filp)

# %%
cv2.imwrite('D:/data/random_image.png', normalized_gray_gt)
# Out:
# True

# %%
gt = cv2.imread("D:/data/random_image.png")
ud=(gt*255).astype("np.unit8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 gt = cv2.imread("D:/data/random_image.png")
# ----> 2 ud=(gt*255).astype("np.unit8")
#
# TypeError: data type 'np.unit8' not understood

# %%
ud=(gt*255).astype(np.uint8)

# %%
 plt.imshow(ud)
